# %%
import pandas as pd
import numpy as np
import sqlite3 as sq

# %%
df = pd.read_csv('../data/clients.csv')
df
# Out:
#           №                       Полное наименование Компании  \
# 0       1.0  Индивидуальный предприниматель Иванова Зоя Ник...
# 1       NaN                                                NaN
# 2       2.0  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ МИКРО...
# 3       NaN                                                NaN
# 4       3.0   Общество с ограниченной ответственностью "Хэйхэ"
# ...     ...                                                ...
# 1705  786.0  Администрация муниципального образования "Нико...
# 1706    NaN                                                NaN
# 1707  787.0  Индивидуальный предприниматель Осепашвили Дмит...
# 1708    NaN                                                NaN
# 1709  788.0  Общество с ограниченной ответственностью "Груп...
#
#                           Краткое наименование Компании  ИНН Компании  \
# 0     Индивидуальный предприниматель Иванова Зоя Ник...  1.410002e+11
# ...

# %%
df = df.dropna(how='all')
df.head(5)
# Out:
#      №                       Полное наименование Компании  \
# 0  1.0  Индивидуальный предприниматель Иванова Зоя Ник...
# 2  2.0  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ МИКРО...
# 4  3.0   Общество с ограниченной ответственностью "Хэйхэ"
# 6  4.0  Общество с ограниченной ответственностью "Школ...
# 8  5.0    Общество с ограниченной ответственностью "ЭЙГЭ"
#
#                        Краткое наименование Компании  ИНН Компании  \
# 0  Индивидуальный предприниматель Иванова Зоя Ник...  1.410002e+11
# 2                                   ООО МКК "СДЕЛКА"  1.435329e+09
# 4                                        ООО "Хэйхэ"  1.435122e+09
# 6                             ООО "Школьное питание"  1.435222e+09
# 8                                         ООО "ЭЙГЭ"  1.417008e+09
#
#    ОГРН Компании  КПП Компании  ОКПО Компании  ОКАТО Компании  ОКФС Компании  \
# 0   3.041410e+14           NaN    137459181.0    9.821850e+10           16.0
# ...

# %%
df = df.reset_index()

# %%
df.rename({'№': 'id'}, axis=1, inplace=True)
# Out:
# /Users/romanokonesnikov/opt/anaconda3/envs/2020-10-illumidesk-env/lib/python3.8/site-packages/pandas/core/frame.py:4295: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
df['id'] = np.arange(1, len(df)+1)
# Out:
# <ipython-input-432-52f4fc9741a8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['id'] = np.arange(1, len(df)+1)

# %%
df.set_index('id', inplace=True)

# %%
New_Labels = ['Field' + str(i) for i in range(295)]

# %%
df.columns = New_Labels

# %%
df.head(5)
# Out:
#                                                Field0  \
# id
# 1   Индивидуальный предприниматель Иванова Зоя Ник...
# 2   ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ МИКРО...
# 3    Общество с ограниченной ответственностью "Хэйхэ"
# 4   Общество с ограниченной ответственностью "Школ...
# 5     Общество с ограниченной ответственностью "ЭЙГЭ"
#
#                                                Field1        Field2  \
# id
# 1   Индивидуальный предприниматель Иванова Зоя Ник...  1.410002e+11
# 2                                    ООО МКК "СДЕЛКА"  1.435329e+09
# 3                                         ООО "Хэйхэ"  1.435122e+09
# 4                              ООО "Школьное питание"  1.435222e+09
# 5                                          ООО "ЭЙГЭ"  1.417008e+09
#
#           Field3       Field4       Field5        Field6  Field7  \
# id
# 1   3.041410e+14          NaN  137459181.0  9.821850e+10    16.0
# 2   1.181447e+12  143501001.0   24900694.0  9.840100e+10    16.0
# ...

# %%
part1 = df.iloc[:, :15]
part1.head(5)
# Out:
#                                                Field0  \
# id
# 1   Индивидуальный предприниматель Иванова Зоя Ник...
# 2   ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ МИКРО...
# 3    Общество с ограниченной ответственностью "Хэйхэ"
# 4   Общество с ограниченной ответственностью "Школ...
# 5     Общество с ограниченной ответственностью "ЭЙГЭ"
#
#                                                Field1        Field2  \
# id
# 1   Индивидуальный предприниматель Иванова Зоя Ник...  1.410002e+11
# 2                                    ООО МКК "СДЕЛКА"  1.435329e+09
# 3                                         ООО "Хэйхэ"  1.435122e+09
# 4                              ООО "Школьное питание"  1.435222e+09
# 5                                          ООО "ЭЙГЭ"  1.417008e+09
#
#           Field3       Field4       Field5        Field6  Field7  \
# id
# 1   3.041410e+14          NaN  137459181.0  9.821850e+10    16.0
# 2   1.181447e+12  143501001.0   24900694.0  9.840100e+10    16.0
# ...

# %%
conn = sq.connect('data_tables.db')
part1.to_sql('part1', conn, if_exists='replace')

# %%
conn = sq.connect('data_tables.db')
#part1 = pd.read_sql('SELECT * FROM part1', conn)

# %%
cur = conn.cursor()
cur.execute('''SELECT * FROM part1''')

# %%
print(cur.fetchall())
# Out:
# [(1, 'Индивидуальный предприниматель Иванова Зоя Николаевна', 'Индивидуальный предприниматель Иванова Зоя Николаевна', 141000186080.0, 304141021500011.0, None, 137459181.0, 98218501000.0, 16.0, 98618101001.0, 4210015.0, 50102.0, 'Индивидуальные предприниматели', None, 'Прочие виды полиграфической деятельности', '18.12;46.49.32;47.29;47.41;47.43;47.54;47.61;47.78.1;58.11.1;58.14;58.19;73.11;74.20;79.11;82.99;95.11'), (2, 'ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ МИКРОКРЕДИТНАЯ КОМПАНИЯ "СДЕЛКА"', 'ООО МКК "СДЕЛКА"', 1435329441.0, 1181447001724.0, 143501001.0, 24900694.0, 98401000000.0, 16.0, 98701000001.0, 4210014.0, 12300.0, 'Общества с ограниченной ответственностью', None, 'Деятельность микрофинансовая', '64.92.7'), (3, 'Общество с ограниченной ответственностью "Хэйхэ"', 'ООО "Хэйхэ"', 1435121884.0, 1031402027392.0, 143501001.0, 55666832.0, 98401000000.0, 24.0, 98701000001.0, 4210011.0, 12300.0, 'Общества с ограниченной ответственностью', 520000.0, 'Деятельность ресторанов и услуги 
# ...

# %%
part2 = df.iloc[:, 15:31]
part2.head(5)
# Out:
#          Field15       Field16          Field17   Field18 Field19  Field20  \
# id
# 1   1.601000e+10  1.400100e+14  982180400125515  02.08.04     NaN   1445.0
# 2   1.603411e+10  1.400362e+14              NaN  08.02.18     NaN   1447.0
# 3   1.603403e+10  1.435005e+14              NaN  08.01.03     NaN   1447.0
# 4   1.603406e+10  1.435017e+14              NaN  16.11.09     NaN   1447.0
# 5   1.601708e+10  1.400170e+14  984011000041238  07.05.10     NaN   1447.0
#
#                                               Field21   Field22      Field23  \
# id
# 1   Межрайонная инспекция Федеральной налоговой сл...  02.08.04          NaN
# 2   Межрайонная инспекция Федеральной налоговой сл...  08.02.18  143501001.0
# 3   Межрайонная инспекция Федеральной налоговой сл...  18.09.01  143501001.0
# 4   Межрайонная инспекция Федеральной налоговой сл...  16.11.09  143501001.0
# 5   Межрайонная инспекция Федеральной налоговой сл...  07.05.10  141701001.0
#
# ...

# %%
conn = sq.connect('data_tables.db')
part2.to_sql('part2', conn, if_exists='replace')

# %%
conn = sq.connect('data_tables.db')

# %%
cur = conn.cursor()
cur.execute('''SELECT * FROM part2''')

# %%
print(cur.fetchall())
# Out:
# [(1, 16010004056.0, 140010001214003.0, '982180400125515', '02.08.04', None, 1445.0, 'Межрайонная инспекция Федеральной налоговой службы № 3 по Республике Саха (Якутия)', '02.08.04', None, 1447.0, 'Межрайонная инспекция Федеральной налоговой службы № 5 по Республике Саха (Якутия)', '01.01.01', None, '14 002029673', '02.08.04', None), (2, 16034105069.0, 140036246514001.0, None, '08.02.18', None, 1447.0, 'Межрайонная инспекция Федеральной налоговой службы № 5 по Республике Саха (Якутия)', '08.02.18', 143501001.0, 1447.0, 'Межрайонная инспекция Федеральной налоговой службы № 5 по Республике Саха (Якутия)', '01.01.01', None, None, '08.02.18', None), (3, 16034032369.0, 143500491214001.0, None, '08.01.03', None, 1447.0, 'Межрайонная инспекция Федеральной налоговой службы № 5 по Республике Саха (Якутия)', '18.09.01', 143501001.0, 1447.0, 'Межрайонная инспекция Федеральной налоговой службы № 5 по Республике Саха (Якутия)', '01.01.01', None, '14 002038018', '10.09.01', None), (4, 16034055670.0
# ...

# %%
part3 = df.iloc[:, 31:55]
#part3.head(5)

# %%
conn = sq.connect('data_tables.db')
part3.to_sql('part3', conn, if_exists='replace')

# %%
part4 = df.iloc[:, 55:71]
part4.head(5)
# Out:
#                                         Field55   Field56  Field57  \
# id
# 1                                           NaN       NaN      NaN
# 2   143001897130 Дьячковский Николай Николаевич  15.02.19      NaN
# 3                                           NaN       NaN      NaN
# 4        143504004329 Петрова Наталья Ильинична  16.11.09      NaN
# 5          141701185254 Бережнев Семен Иванович  07.05.10      NaN
#
#                  Field58                                        Field59  \
# id
# 1                    NaN                                            NaN
# 2   Генеральный Директор  Бенефициарный владелец;Бенефициарный владелец
# 3                    NaN                         Бенефициарный владелец
# 4               Директор                         Бенефициарный владелец
# 5               Директор                         Бенефициарный владелец
#
#    Field60                                            Field61  \
# id
# ...

# %%
part4.to_sql('part4', conn, if_exists='replace')

# %%
part5 = df.iloc[:, 71:98]
part5.head(5)
# Out:
#     Field71 Field72 Field73 Field74 Field75  Field76 Field77 Field78 Field79  \
# id
# 1       NaN     NaN     NaN     NaN     NaN      NaN     NaN     NaN     NaN
# 2       NaN     NaN     NaN     NaN     NaN      NaN     NaN     NaN     NaN
# 3       NaN     NaN     NaN     NaN     NaN      NaN     NaN     NaN     NaN
# 4       NaN     NaN     NaN     NaN     NaN      NaN     NaN     NaN     NaN
# 5       NaN     NaN     NaN     NaN     NaN      NaN     NaN     NaN     NaN
#
#    Field80  ... Field88 Field89 Field90  \
# id          ...
# 1      NaN  ...     NaN     NaN     NaN
# 2      NaN  ...     NaN     NaN     NaN
# 3      NaN  ...     NaN     NaN     NaN
# 4      NaN  ...     NaN     NaN     NaN
# 5      NaN  ...     NaN     NaN     NaN
#
#                                               Field91  \
# id
# 1                                                 NaN
# 2   Итого;Прочие расходы;Прочее;Валовая прибыль (у...
# 3                                                 NaN
# ...

# %%
part5.to_sql('part5', conn, if_exists='replace')

# %%
part5
# Out:
#      Field71                                            Field72 Field73  \
# id
# 1        NaN                                                NaN     NaN
# 2        NaN                                                NaN     NaN
# 3        NaN                                                NaN     NaN
# 4        NaN                                                NaN     NaN
# 5        NaN                                                NaN     NaN
# ..       ...                                                ...     ...
# 925      NaN                                                NaN     NaN
# 926      NaN                                                NaN     NaN
# 927      NaN  17979/19/14020-ИП;17392/19/14020-ИП;45727/20/1...     NaN
# 928      NaN                                                NaN     NaN
# 929      NaN                                                NaN     NaN
#
#                         Field74              Field75  Field76  \
# id
# ...

# %%
part6 = df.iloc[:, 98:123]
#part6.head(5)

# %%
part6.to_sql('part6', conn, if_exists='replace')

# %%
part7 = df.iloc[:, 123:145]
#part7.head(5)

# %%
part7.to_sql('part7', conn, if_exists='replace')

# %%
part8 = df.iloc[:, 145:156]
#part8.head(5)

# %%
part8.to_sql('part8', conn, if_exists='replace')

# %%
part9 = df.iloc[:, 156:182]
#part9.head(5)

# %%
part9.to_sql('part9', conn, if_exists='replace')

# %%
part10 = df.iloc[:, 182:202]
#part10.head(5)

# %%
part10.to_sql('part10', conn, if_exists='replace')

# %%
part11 = df.iloc[:, 202:211]
#part11.head(5)

# %%
part11.to_sql('part11', conn, if_exists='replace')

# %%
part12 = df.iloc[:, 211:221]
#part12.head(5)

# %%
part12.to_sql('part12', conn, if_exists='replace')

# %%
part13 = df.iloc[:, 221:234]
#part13.head(5)

# %%
part13.to_sql('part13', conn, if_exists='replace')

# %%
part14 = df.iloc[:, 234:256]
#part14.head(5)

# %%
part14.to_sql('part14', conn, if_exists='replace')

# %%
part15 = df.iloc[:, 256:275]
#part15.head(5)

# %%
part15.to_sql('part15', conn, if_exists='replace')

# %%
part16 = df.iloc[:, 275:294]
#part16.head(5)

# %%
part16.to_sql('part16', conn, if_exists='replace')

# %%
cur = conn.cursor()
cur.execute(''' SELECT "field0" FROM part1''')

# %%
print(cur.fetchall())
# Out:
# [('Индивидуальный предприниматель Иванова Зоя Николаевна',), ('ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ МИКРОКРЕДИТНАЯ КОМПАНИЯ "СДЕЛКА"',), ('Общество с ограниченной ответственностью "Хэйхэ"',), ('Общество с ограниченной ответственностью "Школьное питание"',), ('Общество с ограниченной ответственностью "ЭЙГЭ"',), ('ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "СК МОДУЛЬ"',), ('ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "А-СТРОЙ"',), ('ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ЯКУТСКАЯ ТРАНСПОРТНО-СТРОИТЕЛЬНАЯ КОМПАНИЯ"',), ('АКЦИОНЕРНОЕ ОБЩЕСТВО "ЯКУТРЕМБЫТТЕХНИКА"',), ('ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ГАРАНТМЕХАНИЗАЦИЯ"',), ('Муниципальное учреждение "Районный информационно-методический Центр культурно - досуговой сферы Мегино-Кангаласского улуса"',), ('ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ЭНЕРГО-СЕРВИСНАЯ КОМПАНИЯ ПРОФИТ"',), ('Общественная организация "Молодежный союз юристов Республики Саха (Якутия)"',), ('ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "СНАБФУД"',), ('Индивид
# ...

# %%
for i in [1:16]

part16.to_sql('part16', conn, if_exists='replace')

# %%
! sqlite3 part1.db .dump > part1.sql

# %%
! sqlite3 short_data.db .dump > short_data.sql

# %%
! sqlite3 data_tables.db .dump > data_tables.sql

# %%
df.head(5)
# Out:
#                                                Field0  \
# id
# 1   Индивидуальный предприниматель Иванова Зоя Ник...
# 2   ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ МИКРО...
# 3    Общество с ограниченной ответственностью "Хэйхэ"
# 4   Общество с ограниченной ответственностью "Школ...
# 5     Общество с ограниченной ответственностью "ЭЙГЭ"
#
#                                                Field1        Field2  \
# id
# 1   Индивидуальный предприниматель Иванова Зоя Ник...  1.410002e+11
# 2                                    ООО МКК "СДЕЛКА"  1.435329e+09
# 3                                         ООО "Хэйхэ"  1.435122e+09
# 4                              ООО "Школьное питание"  1.435222e+09
# 5                                          ООО "ЭЙГЭ"  1.417008e+09
#
#           Field3       Field4       Field5        Field6  Field7  \
# id
# 1   3.041410e+14          NaN  137459181.0  9.821850e+10    16.0
# 2   1.181447e+12  143501001.0   24900694.0  9.840100e+10    16.0
# ...

# %%
df['Rating'] = pd.Series(data=np.full(len(df['Field0']), 10000), index=df.index)
# Out:
# <ipython-input-437-accfa83fea08>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Rating'] = pd.Series(data=np.full(len(df['Field0']), 10000), index=df.index)

# %%
df
# Out:
#                                                 Field0  \
# id
# 1    Индивидуальный предприниматель Иванова Зоя Ник...
# 2    ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ МИКРО...
# 3     Общество с ограниченной ответственностью "Хэйхэ"
# 4    Общество с ограниченной ответственностью "Школ...
# 5      Общество с ограниченной ответственностью "ЭЙГЭ"
# ..                                                 ...
# 925   Общество с ограниченной ответственностью "Мебко"
# 926  Общество с ограниченной ответственностью "Выбо...
# 927  Администрация муниципального образования "Нико...
# 928  Индивидуальный предприниматель Осепашвили Дмит...
# 929  Общество с ограниченной ответственностью "Груп...
#
#                                                 Field1        Field2  \
# id
# 1    Индивидуальный предприниматель Иванова Зоя Ник...  1.410002e+11
# 2                                     ООО МКК "СДЕЛКА"  1.435329e+09
# 3                                          ООО "Хэйхэ"  1.435122e+09
# ...

# %%
df.Field37.value_counts()
# Out:
# False    570
# True       3
# Name: Field37, dtype: int64

# %%
df.Field38.value_counts()
# Out:
# False    566
# True       7
# Name: Field38, dtype: int64

# %%
df.Rating.value_counts()
# Out:
# 10500    912
# 10000     16
# 0          1
# Name: Rating, dtype: int64

# %%
df.loc[df['Field37'] == True, 'Rating'] = 0
# Out:
# /Users/romanokonesnikov/opt/anaconda3/envs/2020-10-illumidesk-env/lib/python3.8/site-packages/pandas/core/indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)

# %%
df.loc[df['Field38'] == True, 'Rating'] = 0

# %%
df.Field73.value_counts()
# Out:
# 45780/17/24090-СД                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     
# ...

# %%
df.loc[df.Field73.isna() == True, 'Rating'] = 10500
# Out:
# /Users/romanokonesnikov/opt/anaconda3/envs/2020-10-illumidesk-env/lib/python3.8/site-packages/pandas/core/indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)

# %%
df.Field73.isna() == False
df.Field1 == df.Field82
df.Field76

# %%
df.Field73.isna()
# Out:
# True     912
# False     17
# Name: Field73, dtype: int64

# %%
df.Field75
# Out:
# id
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# 5                      NaN
#               ...
# 925                    NaN
# 926                    NaN
# 927    123,93;500,00;13,40
# 928                    NaN
# 929                    NaN
# Name: Field75, Length: 929, dtype: object

# %%
df.Field75.str.replace(r'[,;]', ' ')
# Out:
# id
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# 5                      NaN
#               ...
# 925                    NaN
# 926                    NaN
# 927    123 93 500 00 13 40
# 928                    NaN
# 929                    NaN
# Name: Field75, Length: 929, dtype: object

# %%
df.Field75

# %%
df.Field75 = pd.to_numeric(df.Field75.str.replace(r'[,;]', ' '))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "500 00"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-428-8b10800271c7> in <module>
# ----> 1 df.Field75 = pd.to_numeric(df.Field75.str.replace(r'[,;]', ' '))
#
# ~/opt/anaconda3/envs/2020-10-illumidesk-env/lib/python3.8/site-packages/pandas/core/tools/numeric.py in to_numeric(arg, errors, downcast)
#     150         coerce_numeric = errors not in ("ignore", "raise")
#     151         try:
# --> 152             values = lib.maybe_convert_numeric(
#     153                 values, set(), coerce_numeric=coerce_numeric
#     154             )
#
# ...

# %%
df.loc[df.Field73.isna() == False, 'Rating'] = 10000+0.005*
# Out:
#                                                 Field0  \
# id
# 1    Индивидуальный предприниматель Иванова Зоя Ник...
# 2    ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ МИКРО...
# 3     Общество с ограниченной ответственностью "Хэйхэ"
# 4    Общество с ограниченной ответственностью "Школ...
# 5      Общество с ограниченной ответственностью "ЭЙГЭ"
# ..                                                 ...
# 925   Общество с ограниченной ответственностью "Мебко"
# 926  Общество с ограниченной ответственностью "Выбо...
# 927  Администрация муниципального образования "Нико...
# 928  Индивидуальный предприниматель Осепашвили Дмит...
# 929  Общество с ограниченной ответственностью "Груп...
#
#                                                 Field1        Field2  \
# id
# 1    Индивидуальный предприниматель Иванова Зоя Ник...  1.410002e+11
# 2                                     ООО МКК "СДЕЛКА"  1.435329e+09
# 3                                          ООО "Хэйхэ"  1.435122e+09
# ...
